# %% [markdown]
# # Learned 0D Parameter Comparison
#
# This notebook demonstrates a smaller, but representative workflow that does not include the calibration or forward simulation steps, which require the external binaries `svzerodcalibrator` and `svzerodsolver`.
#
# We start with the standard 0D input file and pre-calibrated 0D input files for a small "proof of concept" dataset containing five aortic geometries. From these, we extract the inputs (geometric features) and outputs (optimal lumped parameters) for the neural network and assign four geometries to a train set and one to a test set. We then train the neural network, and run inference on the unseen test geometry.
#
# We include a bar chart that shows, for each vessel and junction element in the vasculature, the standard, calibrated (optimal), and learned values of Poiseuille resistance **R**, quadratic resistance **S**, and inductance **L**. We see that, even for this small training dataset, the learned values are closer to the optimal ones than the standard values.
#
# The plot compares five parameter sets:
#
# - **Standard** — lumped parameters from the geometric 0D model (vessel dimensions only, no calibration)
# - **Calibrated** — optimal parameters from svZeroD calibration against 1D flow data (bundled ground truth)
# - **Learned junctions** — neural-network predictions for junction **R**, **S**, and **L** only
# - **Learned junctions and vessels** — neural-network predictions for both junction and vessel parameters
# - **Learned Vessels** — standard junction parameters with vessel **R**, **S**, and **L** replaced by the vessel NN
#
# **Requirements:** `pip install -e ".[dev,notebook]"`, JAX (`jax[cpu]`). Bundled per geometry: `standard-0d` seed JSON, `bifurcations_EL_calibrated_output_BloodVesselJunction.json`, and `oneD/VMR/<geo>/unsteady_soln.vtp` (setup cell). The next section derives `bifurcations_EL_geometric_input.json` from standard-0d + VTP — no svZeroDPlus for that topology step.
#
# Change `SEED` in the setup cell to pick the held-out geometry (4 train / 1 val at 80% split). Examples: `0 → 0154_0001`, `1 → 0175_0000`, `3 → 0129_0000`, `8 → 0176_0000`.

# %% [markdown]
# For reference, here is an image of the test geometry with SEED = 0 (0154_0001).
#
# <img src="assets/0154_0001.png" alt="Test geometry 0154_0001 (SEED = 0)" width="80%">

# %% [markdown]
# ## Setup
#
# Imports, paths, train/val split (`SEED`), and verification of bundled inputs per geometry (standard-0d JSON, calibrated JSON, 1D VTP). See `data/README.md` if files are missing.

# %%
from __future__ import annotations

import json
import subprocess
import sys

from IPython.display import Image, display

from learn_lpns import get_pipeline_config, repo_root
from learn_lpns.data_processing.generate_split_indices import generate_geometry_split
from learn_lpns.tools.basic import load_dict
from learn_lpns.visualizations.plot_zero_d_parameter_bars import plot_zero_d_parameter_bars
from learn_lpns.zerod_calibration.modality_paths import (
    NN_JUNCTION_AND_VESSEL_SUFFIX,
    NN_JUNCTION_ONLY_SUFFIX,
    NN_VESSEL_ONLY_SUFFIX,
)
from learn_lpns.zerod_calibration.nn_inference import run_junction_inference, run_vessel_inference

SET_NAME = "VMR_aortas"
RUN_CONFIG = "gen_loss"
GEOMETRY_VARIANT = "bifurcations_EL"
JUNCTION_TYPE = "BloodVesselJunction"
NUM_GEOS = 5
SEED = 0  # change this; examples: 0→0154_0001, 1→0175_0000, 3→0129_0000, 8→0176_0000

GEOMETRIES = sorted(["0129_0000", "0154_0001", "0174_0000", "0175_0000", "0176_0000"])

cfg = get_pipeline_config(set_name=SET_NAME)
percent_train = cfg.split.data_processing_percent_train

train_geos, val_geos = generate_geometry_split(percent_train, SEED, GEOMETRIES)
if len(val_geos) != 1:
    raise ValueError(f"Expected exactly one validation geometry, got {val_geos}")
VAL_GEO = val_geos[0]

print(f"percent_train={percent_train}, seed={SEED}")
print(f"Train ({len(train_geos)}): {train_geos}")
print(f"Val   ({len(val_geos)}): {val_geos}  -> plot target {VAL_GEO}")

ROOT = repo_root()
DATA_ROOT = ROOT / "data"
ZERO_D_BASE = DATA_ROOT / "zeroD" / SET_NAME / RUN_CONFIG
MODEL_DIR = ROOT / "results" / "models" / "notebook_demo" / SET_NAME / f"{GEOMETRY_VARIANT}_trial_{SEED}"
VESSEL_MODEL_DIR = ROOT / "results" / "models" / "notebook_demo" / SET_NAME / f"{GEOMETRY_VARIANT}_vessel_trial_{SEED}"
PLOT_DIR = ROOT / "results" / "notebook_demo" / "param_comparison" / RUN_CONFIG / SET_NAME / f"seed_{SEED}" / VAL_GEO

# Verify bundled inputs (standard-0d + calibrated + 1D VTP)
CALIBRATED_JSON = "calibrated_output_BloodVesselJunction.json"

STANDARD_0D_DIR = DATA_ROOT / "zeroD" / SET_NAME / "standard-0d"
ONE_D_VMR_DIR = DATA_ROOT / "oneD" / "VMR"

missing = []
for geo in GEOMETRIES:
    std_json = STANDARD_0D_DIR / f"{geo}.json"
    if not std_json.is_file():
        missing.append(str(std_json))
    calib_json = ZERO_D_BASE / geo / CALIBRATED_JSON
    if not calib_json.is_file():
        missing.append(str(calib_json))
    centerline_vtp = ONE_D_VMR_DIR / geo / "unsteady_soln.vtp"
    if not centerline_vtp.is_file():
        missing.append(str(centerline_vtp))

if missing:
    raise FileNotFoundError(
        "Missing bundled demo inputs (standard-0d + calibrated JSON + 1D VTP):\n  "
        + "\n  ".join(missing)
        + "\n\nSee data/README.md — these files ship with the repo under data/."
    )

print(f"OK: {len(GEOMETRIES)} geometries × (standard-0d + {CALIBRATED_JSON} + unsteady_soln.vtp)")
# Out:
# percent_train=0.8, seed=0
# Train (4): ['0129_0000', '0174_0000', '0175_0000', '0176_0000']
# Val   (1): ['0154_0001']  -> plot target 0154_0001
# OK: 5 geometries × (standard-0d + calibrated_output_BloodVesselJunction.json + unsteady_soln.vtp)

# %% [markdown]
# ## 1. Geometric Pre-Processing
#
# Pre-processing steps are applied to the standard 0D files.  First, any junctions with more than two outlets are split into a series for bifurcations.  Next, the junction boundaries are extended into the outlet vessels by pseudo-entrance length to avoid noise caused by local 3D effects common in the splitting zone.

# %%
from learn_lpns.zerod_calibration.materialize_bifurcations_el import (
    default_centerline_path,
    materialize_bifurcations_el_from_base,
)

GEO_JSON = "bifurcations_EL_geometric_input.json"

for geo in GEOMETRIES:
    geo_dir = ZERO_D_BASE / geo
    geo_dir.mkdir(parents=True, exist_ok=True)
    centerline = default_centerline_path(DATA_ROOT, geo)

    materialize_bifurcations_el_from_base(
        base_json_path=str(STANDARD_0D_DIR / f"{geo}.json"),
        centerline_path=str(centerline),
        output_bifurcations_el_path=str(geo_dir / GEO_JSON),
        apply_standard_sim_params=True,
        extract_geometric_params=True,
        convert_bifurcations_junctions=True,
        verbose=False,
    )

print(f"Done: built geometric bifurcations_EL input for {len(GEOMETRIES)} geometries.")
# Out:
#   0129_0000: wrote bifurcations_geometric_input.json
#   0129_0000: wrote bifurcations_EL_geometric_input.json
#   0154_0001: wrote bifurcations_geometric_input.json
#   0154_0001: wrote bifurcations_EL_geometric_input.json
#   0174_0000: wrote bifurcations_geometric_input.json
#   0174_0000: wrote bifurcations_EL_geometric_input.json
#   0175_0000: wrote bifurcations_geometric_input.json
#   0175_0000: wrote bifurcations_EL_geometric_input.json
#   0176_0000: wrote bifurcations_geometric_input.json
#   0176_0000: wrote bifurcations_EL_geometric_input.json
# Done: built geometric bifurcations_EL input for 5 geometries.

# %% [markdown]
# ## 2. Calibration
#
# This step generate a 0D input file (json) that contains the calibrated resistances and inductances (R, S, and L) that best reproduce the results of the high-fidelity 3D simulation (projected first onto the 1D centerline (user-provided input), and then onto the 0D nodes (done by learn_lpns)).
#
# This step requires the `svzerodcalibrator` binary so we skip it here and provide the pre-calibrated 0D input file.

# %% [markdown]
# ## 3. Build Neural Network Training Data
#
# For each junction and vessel element in each geometry we extract the geometric features (from the centerline geometry) and the ground-truth resistance and inductance values (from the calibrated 0D input file).  These are the inputs and outputs of the neural network.  We organize them into human-readable csvs and jax arrays.  We also split the data into a train and validation set.  All elements from the same geometry belong to the same set.

# %%
cmd = [
    sys.executable,
    "-m",
    "learn_lpns.data_processing.run_data_processing",
    "--set_name",
    SET_NAME,
    "--geometry_variant",
    GEOMETRY_VARIANT,
    "--run_config",
    RUN_CONFIG,
    "--percent_train",
    str(percent_train),
    "--seed",
    str(SEED),
]
print(" ".join(cmd))
subprocess.run(cmd, cwd=ROOT, check=True)

jax_path = (
    DATA_ROOT / "jax_arrays" / SET_NAME / RUN_CONFIG / GEOMETRY_VARIANT / "all" / f"jax_arrays_num_geos_{NUM_GEOS}.pkl"
)
split_path = (
    DATA_ROOT
    / "split_indices"
    / SET_NAME
    / RUN_CONFIG
    / GEOMETRY_VARIANT
    / "all"
    / f"train_val_ind_{SET_NAME}_num_geos_{NUM_GEOS}"
)
assert jax_path.is_file(), jax_path
assert split_path.is_file(), split_path
print(f"jax_arrays: {jax_path}")
print(f"split:      {split_path}")
# Out:
# /Users/natalia/cursor_access/learn_lpns/.venv/bin/python -m learn_lpns.data_processing.run_data_processing --set_name VMR_aortas --geometry_variant bifurcations_EL --run_config gen_loss --percent_train 0.8 --seed 0
#
# ================================================================================
# Processing geometry variant: bifurcations_EL
# ================================================================================
# Auto-discovering geometries with both CSV files for VMR_aortas/bifurcations_EL...
#   Found 5 geometries: ['0129_0000', '0154_0001', '0174_0000', '0175_0000', '0176_0000']
# Running data processing pipeline for VMR_aortas/bifurcations_EL with 5 geometries
# Processing geometry 0129_0000
# Loaded 6 junctions with 48 features
# Saved features to data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0129_0000/geometric_features.csv
# Saved geometric features meta to data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0129_0000/geometric_features_meta.csv
# Loaded 6 junctions with 7 target values
#   ✓ Consistency check passed: 6 rows — junction names, primary outlets, and outlet_vessel_ids all match
# Saved targets to data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0129_0000/junction_lumped_parameters.csv
# Saved targets meta to data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0129_0000/junction_lumped_parameters_meta.csv
# Saved vessel features and targets to data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0129_0000/vessel_geometric_features.csv, data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0129_0000/vessel_lumped_parameters.csv
# Processing geometry 0154_0001
# Loaded 5 junctions with 48 features
# Saved features to data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0154_0001/geometric_features.csv
# Saved geometric features meta to data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0154_0001/geometric_features_meta.csv
# Loaded 5 junctions with 7 target values
#   ✓ Consistency check passed: 5 rows — junction names, primary outlets, and outlet_vessel_ids all match
# Saved targets to data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0154_0001/junction_lumped_parameters.csv
# Saved targets meta to data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0154_0001/junction_lumped_parameters_meta.csv
# Saved vessel features and targets to data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0154_0001/vessel_geometric_features.csv, data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0154_0001/vessel_lumped_parameters.csv
# Processing geometry 0174_0000
# Loaded 6 junctions with 48 features
# Saved features to data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0174_0000/geometric_features.csv
# Saved geometric features meta to data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0174_0000/geometric_features_meta.csv
# Loaded 6 junctions with 7 target values
#   ✓ Consistency check passed: 6 rows — junction names, primary outlets, and outlet_vessel_ids all match
# Saved targets to data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0174_0000/junction_lumped_parameters.csv
# Saved targets meta to data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0174_0000/junction_lumped_parameters_meta.csv
# Saved vessel features and targets to data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0174_0000/vessel_geometric_features.csv, data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0174_0000/vessel_lumped_parameters.csv
# Processing geometry 0175_0000
# Loaded 6 junctions with 48 features
# Saved features to data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0175_0000/geometric_features.csv
# Saved geometric features meta to data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0175_0000/geometric_features_meta.csv
# Loaded 6 junctions with 7 target values
#   ✓ Consistency check passed: 6 rows — junction names, primary outlets, and outlet_vessel_ids all match
# Saved targets to data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0175_0000/junction_lumped_parameters.csv
# Saved targets meta to data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0175_0000/junction_lumped_parameters_meta.csv
# Saved vessel features and targets to data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0175_0000/vessel_geometric_features.csv, data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0175_0000/vessel_lumped_parameters.csv
# Processing geometry 0176_0000
# Loaded 6 junctions with 48 features
# Saved features to data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0176_0000/geometric_features.csv
# Saved geometric features meta to data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0176_0000/geometric_features_meta.csv
# Loaded 6 junctions with 7 target values
#   ✓ Consistency check passed: 6 rows — junction names, primary outlets, and outlet_vessel_ids all match
# Saved targets to data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0176_0000/junction_lumped_parameters.csv
# Saved targets meta to data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0176_0000/junction_lumped_parameters_meta.csv
# Saved vessel features and targets to data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0176_0000/vessel_geometric_features.csv, data/ml_inputs/VMR_aortas/gen_loss/bifurcations_EL/0176_0000/vessel_lumped_parameters.csv
#   Saved data summary to data/feature_histograms/VMR_aortas/gen_loss/bifurcations_EL/all/data_summary_VMR_aortas_num_geos_5.csv
# Wrote data_dict to data/jax_arrays/VMR_aortas/gen_loss/bifurcations_EL/all/jax_arrays_num_geos_5.pkl
#   Saved data summary to data/feature_histograms/VMR_aortas/gen_loss/bifurcations_EL/all/data_summary_vessel_VMR_aortas_num_geos_5.csv
# Wrote vessel data_dict to data/jax_arrays/VMR_aortas/gen_loss/bifurcations_EL/all/jax_arrays_vessel_num_geos_5.pkl (n_vessel_rows=24)
# Wrote split indices to data/split_indices/VMR_aortas/gen_loss/bifurcations_EL/all/train_val_ind_VMR_aortas_num_geos_5 (n_train=24, n_val=5)
# Wrote geometry set assignment to data/split_indices/VMR_aortas/gen_loss/bifurcations_EL/all/train_val_ind_VMR_aortas_num_geos_5_geometries.txt
# Train geometries: ['0129_0000', '0174_0000', '0175_0000', '0176_0000']
# Validation geometries: ['0154_0001']
# jax_arrays: /Users/natalia/cursor_access/learn_lpns/data/jax_arrays/VMR_aortas/gen_loss/bifurcations_EL/all/jax_arrays_num_geos_5.pkl
# split:      /Users/natalia/cursor_access/learn_lpns/data/split_indices/VMR_aortas/gen_loss/bifurcations_EL/all/train_val_ind_VMR_aortas_num_geos_5

# %% [markdown]
# ## 4. Train Neural Networks
#
# Train six neural networks - one each to predict the linear resistance R, quadratic resistance S, and inductance L for both vessel and junction elements.

# %%
MODEL_DIR.mkdir(parents=True, exist_ok=True)
VESSEL_MODEL_DIR.mkdir(parents=True, exist_ok=True)

junction_cmd = [
    "learn-lpns-train",
    "--set_name",
    SET_NAME,
    "--run_config",
    RUN_CONFIG,
    "--model_dir",
    str(MODEL_DIR),
]
print(" ".join(junction_cmd))
subprocess.run(junction_cmd, cwd=ROOT, check=True)

for i in range(3):
    model_path = MODEL_DIR / f"rri_{SET_NAME}_pred_{i}_model"
    assert model_path.is_file(), model_path
print(f"Junction models saved under {MODEL_DIR}")

vessel_cmd = [
    "learn-lpns-train",
    "--set_name",
    SET_NAME,
    "--run_config",
    RUN_CONFIG,
    "--vessel",
    "--model_dir",
    str(VESSEL_MODEL_DIR),
]
print(" ".join(vessel_cmd))
subprocess.run(vessel_cmd, cwd=ROOT, check=True)

for i in range(3):
    model_path = VESSEL_MODEL_DIR / f"rri_{SET_NAME}_vessel_pred_{i}_model"
    assert model_path.is_file(), model_path
print(f"Vessel models saved under {VESSEL_MODEL_DIR}")
# Out:
# learn-lpns-train --set_name VMR_aortas --run_config gen_loss --model_dir /Users/natalia/cursor_access/learn_lpns/results/models/notebook_demo/VMR_aortas/bifurcations_EL_trial_0
# num_geos: 5
#
# ================================================================================
# Training junction models for geometry variant: bifurcations_EL
# Symmetric loss: overestimate weight = 1.0 for all models
# Generation-weighted loss: ON (scale=1; from --generation_weighted_loss and/or --run_config ..._gen_loss)
# ================================================================================
# Training RRI models (one network per coefficient)...
# training model 1:  Linear Resistor (R)
# 19 input features
#   asymmetric_loss: OFF  (symmetric loss; overestimate weight = 1.0)
#   generation_weighted_loss: ON  (sample weight = 1.0 / 2^generation); generation rows=29
# Number of offsets:  1
# Number of training points:  24
# Number of validation points:  5
# Epoch 0 in 1.38 sec  |  Training set accuracy 7.369861e+01  |  Validation set accuracy 2.300473e+02
# Epoch 1 in 0.03 sec  |  Training set accuracy 6.452010e+01  |  Validation set accuracy 2.022658e+02
# Epoch 2 in 0.03 sec  |  Training set accuracy 4.872682e+01  |  Validation set accuracy 1.244515e+02
# Epoch 3 in 0.03 sec  |  Training set accuracy 5.012079e+01  |  Validation set accuracy 9.361144e+01
# Epoch 4 in 0.03 sec  |  Training set accuracy 4.927266e+01  |  Validation set accuracy 1.363877e+02
# Epoch 233 in 0.03 sec  |  Training set accuracy 9.468058e+00  |  Validation set accuracy 1.521759e+02
# Epoch 234 in 0.03 sec  |  Training set accuracy 9.199588e+00  |  Validation set accuracy 1.474451e+02
# Epoch 235 in 0.03 sec  |  Training set accuracy 9.695976e+00  |  Validation set accuracy 1.509990e+02
# Epoch 236 in 0.03 sec  |  Training set accuracy 9.424689e+00  |  Validation set accuracy 1.444426e+02
# Epoch 237 in 0.03 sec  |  Training set accuracy 1.066422e+01  |  Validation set accuracy 1.594135e+02
# Epoch 238 in 0.03 sec  |  Training set accuracy 1.005691e+01  |  Validation set accuracy 1.390526e+02
# Epoch 239 in 0.03 sec  |  Training set accuracy 1.011955e+01  |  Validation set accuracy 1.554650e+02
# Epoch 240 in 0.03 sec  |  Training set accuracy 9.245708e+00  |  Validation set accuracy 1.459868e+02
# Epoch 241 in 0.03 sec  |  Training set accuracy 1.012328e+01  |  Validation set accuracy 1.495905e+02
# Epoch 242 in 0.03 sec  |  Training set accuracy 9.184401e+00  |  Validation set accuracy 1.430959e+02
# Epoch 243 in 0.03 sec  |  Training set accuracy 9.693903e+00  |  Validation set accuracy 1.543837e+02
# Epoch 244 in 0.03 sec  |  Training set accuracy 9.424870e+00  |  Validation set accuracy 1.477123e+02
# Epoch 245 in 0.03 sec  |  Training set accuracy 9.115829e+00  |  Validation set accuracy 1.437462e+02
# Epoch 246 in 0.03 sec  |  Training set accuracy 9.105163e+00  |  Validation set accuracy 1.486089e+02
# Epoch 247 in 0.03 sec  |  Training set accuracy 8.938799e+00  |  Validation set accuracy 1.483068e+02
# Epoch 248 in 0.03 sec  |  Training set accuracy 8.928440e+00  |  Validation set accuracy 1.476157e+02
# Epoch 249 in 0.03 sec  |  Training set accuracy 8.848273e+00  |  Validation set accuracy 1.461613e+02
# Epoch 250 in 0.03 sec  |  Training set accuracy 8.885411e+00  |  Validation set accuracy 1.429209e+02
# Epoch 251 in 0.03 sec  |  Training set accuracy 8.860254e+00  |  Validation set accuracy 1.445033e+02
# Epoch 252 in 0.03 sec  |  Training set accuracy 9.314930e+00  |  Validation set accuracy 1.502715e+02
# Epoch 253 in 0.03 sec  |  Training set accuracy 8.880265e+00  |  Validation set accuracy 1.464323e+02
# Epoch 254 in 0.03 sec  |  Training set accuracy 8.713879e+00  |  Validation set accuracy 1.460139e+02
# Epoch 255 in 0.03 sec  |  Training set accuracy 8.735646e+00  |  Validation set accuracy 1.458293e+02
# Epoch 256 in 0.03 sec  |  Training set accuracy 8.901955e+00  |  Validation set accuracy 1.433166e+02
# Epoch 257 in 0.03 sec  |  Training set accuracy 8.993364e+00  |  Validation set accuracy 1.499072e+02
# Epoch 258 in 0.03 sec  |  Training set accuracy 9.442016e+00  |  Validation set accuracy 1.410203e+02
# Epoch 259 in 0.03 sec  |  Training set accuracy 9.230716e+00  |  Validation set accuracy 1.470371e+02
# Epoch 260 in 0.03 sec  |  Training set accuracy 8.705828e+00  |  Validation set accuracy 1.409188e+02
# Epoch 261 in 0.03 sec  |  Training set accuracy 8.854460e+00  |  Validation set accuracy 1.456520e+02
# Epoch 262 in 0.03 sec  |  Training set accuracy 8.646237e+00  |  Validation set accuracy 1.460270e+02
# Epoch 263 in 0.03 sec  |  Training set accuracy 9.519844e+00  |  Validation set accuracy 1.377998e+02
# Epoch 264 in 0.03 sec  |  Training set accuracy 1.006708e+01  |  Validation set accuracy 1.541494e+02
# Epoch 265 in 0.03 sec  |  Training set accuracy 1.006514e+01  |  Validation set accuracy 1.341744e+02
# Epoch 266 in 0.03 sec  |  Training set accuracy 9.551045e+00  |  Validation set accuracy 1.477033e+02
# Epoch 267 in 0.03 sec  |  Training set accuracy 8.644004e+00  |  Validation set accuracy 1.411565e+02
# Epoch 268 in 0.03 sec  |  Training set accuracy 8.742404e+00  |  Validation set accuracy 1.443442e+02
# Epoch 269 in 0.03 sec  |  Training set accuracy 8.604538e+00  |  Validation set accuracy 1.440281e+02
# Epoch 270 in 0.03 sec  |  Training set accuracy 8.528117e+00  |  Validation set accuracy 1.414100e+02
# Epoch 271 in 0.03 sec  |  Training set accuracy 8.525398e+00  |  Validation set accuracy 1.410026e+02
# Epoch 272 in 0.03 sec  |  Training set accuracy 8.600126e+00  |  Validation set accuracy 1.403874e+02
# Epoch 273 in 0.03 sec  |  Training set accuracy 8.465821e+00  |  Validation set accuracy 1.422896e+02
# Epoch 274 in 0.03 sec  |  Training set accuracy 8.652803e+00  |  Validation set accuracy 1.497430e+02
# Epoch 275 in 0.03 sec  |  Training set accuracy 8.847361e+00  |  Validation set accuracy 1.406702e+02
# Epoch 276 in 0.03 sec  |  Training set accuracy 8.657307e+00  |  Validation set accuracy 1.476340e+02
# Epoch 277 in 0.03 sec  |  Training set accuracy 8.252961e+00  |  Validation set accuracy 1.438523e+02
# Epoch 278 in 0.03 sec  |  Training set accuracy 8.320491e+00  |  Validation set accuracy 1.454178e+02
# Epoch 279 in 0.03 sec  |  Training set accuracy 8.265934e+00  |  Validation set accuracy 1.439523e+02
# Epoch 280 in 0.03 sec  |  Training set accuracy 8.326783e+00  |  Validation set accuracy 1.416875e+02
# Epoch 281 in 0.03 sec  |  Training set accuracy 9.013840e+00  |  Validation set accuracy 1.506414e+02
# Epoch 282 in 0.03 sec  |  Training set accuracy 8.199135e+00  |  Validation set accuracy 1.425804e+02
# Epoch 283 in 0.03 sec  |  Training set accuracy 8.292575e+00  |  Validation set accuracy 1.458356e+02
# Epoch 284 in 0.03 sec  |  Training set accuracy 8.454457e+00  |  Validation set accuracy 1.438706e+02
# Epoch 285 in 0.03 sec  |  Training set accuracy 8.296082e+00  |  Validation set accuracy 1.442405e+02
# Epoch 286 in 0.03 sec  |  Training set accuracy 9.946430e+00  |  Validation set accuracy 1.349929e+02
# Epoch 287 in 0.03 sec  |  Training set accuracy 9.314212e+00  |  Validation set accuracy 1.319321e+02
# Epoch 288 in 0.03 sec  |  Training set accuracy 9.985798e+00  |  Validation set accuracy 1.510820e+02
# Epoch 289 in 0.03 sec  |  Training set accuracy 9.217117e+00  |  Validation set accuracy 1.500763e+02
# Epoch 290 in 0.03 sec  |  Training set accuracy 8.909943e+00  |  Validation set accuracy 1.416041e+02
# Epoch 291 in 0.03 sec  |  Training set accuracy 8.426468e+00  |  Validation set accuracy 1.409428e+02
# Epoch 292 in 0.03 sec  |  Training set accuracy 8.306574e+00  |  Validation set accuracy 1.458987e+02
# Epoch 293 in 0.03 sec  |  Training set accuracy 9.213822e+00  |  Validation set accuracy 1.515941e+02
# Epoch 294 in 0.03 sec  |  Training set accuracy 8.263852e+00  |  Validation set accuracy 1.402003e+02
# Epoch 295 in 0.03 sec  |  Training set accuracy 8.198955e+00  |  Validation set accuracy 1.410615e+02
# Epoch 296 in 0.03 sec  |  Training set accuracy 8.293702e+00  |  Validation set accuracy 1.399311e+02
# Epoch 297 in 0.03 sec  |  Training set accuracy 8.070457e+00  |  Validation set accuracy 1.406251e+02
# Epoch 298 in 0.03 sec  |  Training set accuracy 8.162958e+00  |  Validation set accuracy 1.428003e+02
# Epoch 299 in 0.03 sec  |  Training set accuracy 8.177078e+00  |  Validation set accuracy 1.394304e+02
# Epoch 300 in 0.03 sec  |  Training set accuracy 8.228132e+00  |  Validation set accuracy 1.392948e+02
# Epoch 301 in 0.03 sec  |  Training set accuracy 8.462062e+00  |  Validation set accuracy 1.453188e+02
# Epoch 302 in 0.03 sec  |  Training set accuracy 8.045735e+00  |  Validation set accuracy 1.406074e+02
# Epoch 303 in 0.03 sec  |  Training set accuracy 8.521739e+00  |  Validation set accuracy 1.452593e+02
# Epoch 304 in 0.03 sec  |  Training set accuracy 8.369195e+00  |  Validation set accuracy 1.377638e+02
# Epoch 305 in 0.03 sec  |  Training set accuracy 8.225425e+00  |  Validation set accuracy 1.435097e+02
# Epoch 306 in 0.03 sec  |  Training set accuracy 7.982483e+00  |  Validation set accuracy 1.397908e+02
# Epoch 307 in 0.03 sec  |  Training set accuracy 8.095715e+00  |  Validation set accuracy 1.411649e+02
# Epoch 308 in 0.03 sec  |  Training set accuracy 8.017653e+00  |  Validation set accuracy 1.414008e+02
# Epoch 309 in 0.03 sec  |  Training set accuracy 7.999009e+00  |  Validation set accuracy 1.431087e+02
# Epoch 310 in 0.03 sec  |  Training set accuracy 8.246829e+00  |  Validation set accuracy 1.446896e+02
# Epoch 311 in 0.03 sec  |  Training set accuracy 8.066707e+00  |  Validation set accuracy 1.392245e+02
# Epoch 312 in 0.03 sec  |  Training set accuracy 8.015162e+00  |  Validation set accuracy 1.395506e+02
# Epoch 313 in 0.03 sec  |  Training set accuracy 7.983579e+00  |  Validation set accuracy 1.368192e+02
# Epoch 314 in 0.03 sec  |  Training set accuracy 8.226705e+00  |  Validation set accuracy 1.441232e+02
# Epoch 315 in 0.03 sec  |  Training set accuracy 8.001887e+00  |  Validation set accuracy 1.369038e+02
# Epoch 316 in 0.03 sec  |  Training set accuracy 8.045460e+00  |  Validation set accuracy 1.402538e+02
# Epoch 317 in 0.03 sec  |  Training set accuracy 7.935889e+00  |  Validation set accuracy 1.370307e+02
# Epoch 318 in 0.03 sec  |  Training set accuracy 8.010489e+00  |  Validation set accuracy 1.426951e+02
# Epoch 319 in 0.03 sec  |  Training set accuracy 8.519319e+00  |  Validation set accuracy 1.330476e+02
# Epoch 320 in 0.03 sec  |  Training set accuracy 7.957281e+00  |  Validation set accuracy 1.391171e+02
# Epoch 321 in 0.03 sec  |  Training set accuracy 8.380572e+00  |  Validation set accuracy 1.429321e+02
# Epoch 322 in 0.03 sec  |  Training set accuracy 8.434476e+00  |  Validation set accuracy 1.354332e+02
# Epoch 323 in 0.03 sec  |  Training set accuracy 8.038762e+00  |  Validation set accuracy 1.375666e+02
# Epoch 324 in 0.03 sec  |  Training set accuracy 9.168411e+00  |  Validation set accuracy 1.337283e+02
# Epoch 325 in 0.03 sec  |  Training set accuracy 9.717708e+00  |  Validation set accuracy 1.494401e+02
# Epoch 326 in 0.03 sec  |  Training set accuracy 8.758352e+00  |  Validation set accuracy 1.344718e+02
# Epoch 327 in 0.03 sec  |  Training set accuracy 8.561272e+00  |  Validation set accuracy 1.429524e+02
# Epoch 328 in 0.03 sec  |  Training set accuracy 8.486979e+00  |  Validation set accuracy 1.359831e+02
# Epoch 329 in 0.03 sec  |  Training set accuracy 8.011471e+00  |  Validation set accuracy 1.412323e+02
# Epoch 330 in 0.03 sec  |  Training set accuracy 7.946851e+00  |  Validation set accuracy 1.361718e+02
# Epoch 331 in 0.03 sec  |  Training set accuracy 8.141792e+00  |  Validation set accuracy 1.412690e+02
# Epoch 332 in 0.03 sec  |  Training set accuracy 8.362899e+00  |  Validation set accuracy 1.368667e+02
# Epoch 333 in 0.03 sec  |  Training set accuracy 7.891784e+00  |  Validation set accuracy 1.395661e+02
# Epoch 334 in 0.03 sec  |  Training set accuracy 8.227707e+00  |  Validation set accuracy 1.323703e+02
# Epoch 335 in 0.03 sec  |  Training set accuracy 8.041314e+00  |  Validation set accuracy 1.401515e+02
# Epoch 336 in 0.03 sec  |  Training set accuracy 7.962274e+00  |  Validation set accuracy 1.358632e+02
# Epoch 337 in 0.03 sec  |  Training set accuracy 8.409434e+00  |  Validation set accuracy 1.407713e+02
# Epoch 338 in 0.03 sec  |  Training set accuracy 8.071627e+00  |  Validation set accuracy 1.387802e+02
# Epoch 339 in 0.03 sec  |  Training set accuracy 8.132339e+00  |  Validation set accuracy 1.408746e+02
# Epoch 340 in 0.03 sec  |  Training set accuracy 8.057521e+00  |  Validation set accuracy 1.339421e+02
# Epoch 341 in 0.03 sec  |  Training set accuracy 8.852702e+00  |  Validation set accuracy 1.441764e+02
# Epoch 342 in 0.03 sec  |  Training set accuracy 8.255656e+00  |  Validation set accuracy 1.359312e+02
# Epoch 343 in 0.03 sec  |  Training set accuracy 8.030112e+00  |  Validation set accuracy 1.430806e+02
# Epoch 344 in 0.03 sec  |  Training set accuracy 8.035913e+00  |  Validation set accuracy 1.363001e+02
# Epoch 345 in 0.03 sec  |  Training set accuracy 8.870712e+00  |  Validation set accuracy 1.491732e+02
# Epoch 346 in 0.03 sec  |  Training set accuracy 9.316415e+00  |  Validation set accuracy 1.447861e+02
# Epoch 347 in 0.03 sec  |  Training set accuracy 1.033153e+01  |  Validation set accuracy 1.465490e+02
# Epoch 348 in 0.03 sec  |  Training set accuracy 1.094552e+01  |  Validation set accuracy 1.237475e+02
# Epoch 349 in 0.03 sec  |  Training set accuracy 1.625272e+01  |  Validation set accuracy 1.604181e+02
# Epoch 350 in 0.03 sec  |  Training set accuracy 1.112010e+01  |  Validation set accuracy 1.228800e+02
# Epoch 351 in 0.03 sec  |  Training set accuracy 8.434140e+00  |  Validation set accuracy 1.402916e+02
# Epoch 352 in 0.03 sec  |  Training set accuracy 9.281857e+00  |  Validation set accuracy 1.526718e+02
# Epoch 353 in 0.03 sec  |  Training set accuracy 9.149570e+00  |  Validation set accuracy 1.475036e+02
# Epoch 354 in 0.03 sec  |  Training set accuracy 9.026309e+00  |  Validation set accuracy 1.339615e+02
# Epoch 355 in 0.03 sec  |  Training set accuracy 7.951618e+00  |  Validation set accuracy 1.381428e+02
# Epoch 356 in 0.03 sec  |  Training set accuracy 8.948526e+00  |  Validation set accuracy 1.405577e+02
# Epoch 357 in 0.03 sec  |  Training set accuracy 8.017187e+00  |  Validation set accuracy 1.361548e+02
# Epoch 358 in 0.03 sec  |  Training set accuracy 8.807197e+00  |  Validation set accuracy 1.318100e+02
# Epoch 359 in 0.03 sec  |  Training set accuracy 7.828914e+00  |  Validation set accuracy 1.330557e+02
# Epoch 360 in 0.03 sec  |  Training set accuracy 8.060899e+00  |  Validation set accuracy 1.385100e+02
# Epoch 361 in 0.03 sec  |  Training set accuracy 7.667269e+00  |  Validation set accuracy 1.345870e+02
# Epoch 362 in 0.03 sec  |  Training set accuracy 7.723028e+00  |  Validation set accuracy 1.340659e+02
# Epoch 363 in 0.03 sec  |  Training set accuracy 7.636351e+00  |  Validation set accuracy 1.355624e+02
# Epoch 364 in 0.03 sec  |  Training set accuracy 7.798505e+00  |  Validation set accuracy 1.376114e+02
# Epoch 365 in 0.03 sec  |  Training set accuracy 7.687519e+00  |  Validation set accuracy 1.347125e+02
# Epoch 366 in 0.03 sec  |  Training set accuracy 7.835254e+00  |  Validation set accuracy 1.376009e+02
# Epoch 367 in 0.03 sec  |  Training set accuracy 7.714653e+00  |  Validation set accuracy 1.361624e+02
# Epoch 368 in 0.03 sec  |  Training set accuracy 7.601285e+00  |  Validation set accuracy 1.348684e+02
# Epoch 369 in 0.03 sec  |  Training set accuracy 7.638336e+00  |  Validation set accuracy 1.377587e+02
# Epoch 370 in 0.03 sec  |  Training set accuracy 7.547825e+00  |  Validation set accuracy 1.353410e+02
# Epoch 371 in 0.03 sec  |  Training set accuracy 7.676809e+00  |  Validation set accuracy 1.382392e+02
# Epoch 372 in 0.03 sec  |  Training set accuracy 7.552339e+00  |  Validation set accuracy 1.353494e+02
# Epoch 373 in 0.03 sec  |  Training set accuracy 7.549012e+00  |  Validation set accuracy 1.338691e+02
# Epoch 374 in 0.03 sec  |  Training set accuracy 7.603604e+00  |  Validation set accuracy 1.359089e+02
# Epoch 375 in 0.03 sec  |  Training set accuracy 7.666921e+00  |  Validation set accuracy 1.347677e+02
# Epoch 376 in 0.03 sec  |  Training set accuracy 7.528585e+00  |  Validation set accuracy 1.360546e+02
# Epoch 377 in 0.03 sec  |  Training set accuracy 7.476604e+00  |  Validation set accuracy 1.339602e+02
# Epoch 378 in 0.03 sec  |  Training set accuracy 7.859949e+00  |  Validation set accuracy 1.376143e+02
# Epoch 379 in 0.03 sec  |  Training set accuracy 7.548775e+00  |  Validation set accuracy 1.339780e+02
# Epoch 380 in 0.03 sec  |  Training set accuracy 7.655212e+00  |  Validation set accuracy 1.368964e+02
# Epoch 381 in 0.03 sec  |  Training set accuracy 7.655825e+00  |  Validation set accuracy 1.312295e+02
# Epoch 382 in 0.03 sec  |  Training set accuracy 7.565561e+00  |  Validation set accuracy 1.375752e+02
# Epoch 383 in 0.03 sec  |  Training set accuracy 7.425456e+00  |  Validation set accuracy 1.364774e+02
# Epoch 384 in 0.03 sec  |  Training set accuracy 7.518773e+00  |  Validation set accuracy 1.369186e+02
# Epoch 385 in 0.03 sec  |  Training set accuracy 7.562527e+00  |  Validation set accuracy 1.349749e+02
# Epoch 386 in 0.03 sec  |  Training set accuracy 7.580735e+00  |  Validation set accuracy 1.346428e+02
# Epoch 387 in 0.03 sec  |  Training set accuracy 7.510221e+00  |  Validation set accuracy 1.328540e+02
# Epoch 388 in 0.03 sec  |  Training set accuracy 7.787704e+00  |  Validation set accuracy 1.371634e+02
# Epoch 389 in 0.03 sec  |  Training set accuracy 7.600605e+00  |  Validation set accuracy 1.327664e+02
# Epoch 390 in 0.03 sec  |  Training set accuracy 7.477952e+00  |  Validation set accuracy 1.340070e+02
# Epoch 391 in 0.03 sec  |  Training set accuracy 8.673381e+00  |  Validation set accuracy 1.444273e+02
# Epoch 392 in 0.03 sec  |  Training set accuracy 8.255332e+00  |  Validation set accuracy 1.324073e+02
# Epoch 393 in 0.03 sec  |  Training set accuracy 8.832980e+00  |  Validation set accuracy 1.375640e+02
# Epoch 394 in 0.03 sec  |  Training set accuracy 7.611042e+00  |  Validation set accuracy 1.338133e+02
# Epoch 395 in 0.03 sec  |  Training set accuracy 9.143544e+00  |  Validation set accuracy 1.341919e+02
# Epoch 396 in 0.03 sec  |  Training set accuracy 7.539952e+00  |  Validation set accuracy 1.339746e+02
# Epoch 397 in 0.03 sec  |  Training set accuracy 7.602704e+00  |  Validation set accuracy 1.366184e+02
# Epoch 398 in 0.03 sec  |  Training set accuracy 7.915824e+00  |  Validation set accuracy 1.409182e+02
# Epoch 399 in 0.03 sec  |  Training set accuracy 7.776484e+00  |  Validation set accuracy 1.378718e+02
# Epoch 400 in 0.03 sec  |  Training set accuracy 7.443234e+00  |  Validation set accuracy 1.350403e+02
# Epoch 401 in 0.03 sec  |  Training set accuracy 7.451739e+00  |  Validation set accuracy 1.356559e+02
# Epoch 402 in 0.03 sec  |  Training set accuracy 7.521921e+00  |  Validation set accuracy 1.338051e+02
# Epoch 403 in 0.03 sec  |  Training set accuracy 7.640423e+00  |  Validation set accuracy 1.356992e+02
# Epoch 404 in 0.03 sec  |  Training set accuracy 7.304945e+00  |  Validation set accuracy 1.346725e+02
# Epoch 405 in 0.03 sec  |  Training set accuracy 7.728796e+00  |  Validation set accuracy 1.383092e+02
# Epoch 406 in 0.03 sec  |  Training set accuracy 7.309857e+00  |  Validation set accuracy 1.355434e+02
# Epoch 407 in 0.03 sec  |  Training set accuracy 7.292397e+00  |  Validation set accuracy 1.354851e+02
# Epoch 408 in 0.03 sec  |  Training set accuracy 7.504790e+00  |  Validation set accuracy 1.375860e+02
# Epoch 409 in 0.03 sec  |  Training set accuracy 7.367970e+00  |  Validation set accuracy 1.348938e+02
# Epoch 410 in 0.03 sec  |  Training set accuracy 7.281785e+00  |  Validation set accuracy 1.342654e+02
# Epoch 411 in 0.03 sec  |  Training set accuracy 7.630017e+00  |  Validation set accuracy 1.361188e+02
# Epoch 412 in 0.03 sec  |  Training set accuracy 7.610054e+00  |  Validation set accuracy 1.353893e+02
# Epoch 413 in 0.03 sec  |  Training set accuracy 7.714302e+00  |  Validation set accuracy 1.350602e+02
# Epoch 414 in 0.03 sec  |  Training set accuracy 8.636109e+00  |  Validation set accuracy 1.364810e+02
# Epoch 415 in 0.03 sec  |  Training set accuracy 7.265610e+00  |  Validation set accuracy 1.363516e+02
# Epoch 416 in 0.03 sec  |  Training set accuracy 1.185335e+01  |  Validation set accuracy 1.349339e+02
# Epoch 417 in 0.03 sec  |  Training set accuracy 9.358254e+00  |  Validation set accuracy 1.372743e+02
# Epoch 418 in 0.03 sec  |  Training set accuracy 1.041880e+01  |  Validation set accuracy 1.347111e+02
# Epoch 419 in 0.03 sec  |  Training set accuracy 1.062360e+01  |  Validation set accuracy 1.398457e+02
# Epoch 420 in 0.03 sec  |  Training set accuracy 1.162986e+01  |  Validation set accuracy 1.374317e+02
# Epoch 421 in 0.03 sec  |  Training set accuracy 1.043671e+01  |  Validation set accuracy 1.330039e+02
# Epoch 422 in 0.03 sec  |  Training set accuracy 1.058682e+01  |  Validation set accuracy 1.291554e+02
# Epoch 423 in 0.03 sec  |  Training set accuracy 9.130770e+00  |  Validation set accuracy 1.433377e+02
# Epoch 424 in 0.03 sec  |  Training set accuracy 8.719151e+00  |  Validation set accuracy 1.407673e+02
# Epoch 425 in 0.03 sec  |  Training set accuracy 7.594929e+00  |  Validation set accuracy 1.393286e+02
# Epoch 426 in 0.03 sec  |  Training set accuracy 7.987906e+00  |  Validation set accuracy 1.341078e+02
# Epoch 427 in 0.03 sec  |  Training set accuracy 7.433753e+00  |  Validation set accuracy 1.315589e+02
# Epoch 428 in 0.03 sec  |  Training set accuracy 7.565814e+00  |  Validation set accuracy 1.377225e+02
# Epoch 429 in 0.03 sec  |  Training set accuracy 7.421309e+00  |  Validation set accuracy 1.391681e+02
# Epoch 430 in 0.03 sec  |  Training set accuracy 7.304705e+00  |  Validation set accuracy 1.365657e+02
# Epoch 431 in 0.03 sec  |  Training set accuracy 7.519935e+00  |  Validation set accuracy 1.323467e+02
# Epoch 432 in 0.03 sec  |  Training set accuracy 7.435397e+00  |  Validation set accuracy 1.356845e+02
# Epoch 433 in 0.03 sec  |  Training set accuracy 7.208711e+00  |  Validation set accuracy 1.357430e+02
# Epoch 434 in 0.03 sec  |  Training set accuracy 7.616032e+00  |  Validation set accuracy 1.381328e+02
# Epoch 435 in 0.03 sec  |  Training set accuracy 7.623246e+00  |  Validation set accuracy 1.360496e+02
# Epoch 436 in 0.03 sec  |  Training set accuracy 7.203147e+00  |  Validation set accuracy 1.361156e+02
# Epoch 437 in 0.03 sec  |  Training set accuracy 7.207127e+00  |  Validation set accuracy 1.344078e+02
# Epoch 438 in 0.03 sec  |  Training set accuracy 7.377348e+00  |  Validation set accuracy 1.325404e+02
# Epoch 439 in 0.03 sec  |  Training set accuracy 7.271864e+00  |  Validation set accuracy 1.336996e+02
# Epoch 440 in 0.03 sec  |  Training set accuracy 7.529937e+00  |  Validation set accuracy 1.382176e+02
# Epoch 441 in 0.03 sec  |  Training set accuracy 7.243655e+00  |  Validation set accuracy 1.336249e+02
# Epoch 442 in 0.03 sec  |  Training set accuracy 7.709972e+00  |  Validation set accuracy 1.404305e+02
# Epoch 443 in 0.03 sec  |  Training set accuracy 7.196105e+00  |  Validation set accuracy 1.365005e+02
# Epoch 444 in 0.03 sec  |  Training set accuracy 7.472677e+00  |  Validation set accuracy 1.364198e+02
# Epoch 445 in 0.03 sec  |  Training set accuracy 7.262328e+00  |  Validation set accuracy 1.337797e+02
# Epoch 446 in 0.03 sec  |  Training set accuracy 7.544408e+00  |  Validation set accuracy 1.348248e+02
# Epoch 447 in 0.03 sec  |  Training set accuracy 7.224237e+00  |  Validation set accuracy 1.377908e+02
# Epoch 448 in 0.03 sec  |  Training set accuracy 7.546363e+00  |  Validation set accuracy 1.370338e+02
# Epoch 449 in 0.03 sec  |  Training set accuracy 7.694003e+00  |  Validation set accuracy 1.401283e+02
# Epoch 450 in 0.03 sec  |  Training set accuracy 7.617478e+00  |  Validation set accuracy 1.313001e+02
# Epoch 451 in 0.03 sec  |  Training set accuracy 8.267043e+00  |  Validation set accuracy 1.433400e+02
# Epoch 452 in 0.03 sec  |  Training set accuracy 7.979379e+00  |  Validation set accuracy 1.381903e+02
# Epoch 453 in 0.03 sec  |  Training set accuracy 7.201390e+00  |  Validation set accuracy 1.381893e+02
# Epoch 454 in 0.03 sec  |  Training set accuracy 7.392530e+00  |  Validation set accuracy 1.350083e+02
# Epoch 455 in 0.03 sec  |  Training set accuracy 7.847860e+00  |  Validation set accuracy 1.418884e+02
# Epoch 456 in 0.03 sec  |  Training set accuracy 7.165885e+00  |  Validation set accuracy 1.358000e+02
# Epoch 457 in 0.03 sec  |  Training set accuracy 7.624735e+00  |  Validation set accuracy 1.356642e+02
# Epoch 458 in 0.03 sec  |  Training set accuracy 7.151203e+00  |  Validation set accuracy 1.373434e+02
# Epoch 459 in 0.03 sec  |  Training set accuracy 7.569158e+00  |  Validation set accuracy 1.393525e+02
# Epoch 460 in 0.03 sec  |  Training set accuracy 7.271727e+00  |  Validation set accuracy 1.354404e+02
# Epoch 486 in 0.02 sec  |  Training set accuracy 4.991757e-01  |  Validation set accuracy 5.042978e-02
# Epoch 487 in 0.02 sec  |  Training set accuracy 2.052175e-01  |  Validation set accuracy 3.341351e-02
# Epoch 488 in 0.02 sec  |  Training set accuracy 2.169531e-01  |  Validation set accuracy 3.306600e-02
# Epoch 489 in 0.02 sec  |  Training set accuracy 3.676964e-01  |  Validation set accuracy 3.206810e-02
# Epoch 490 in 0.02 sec  |  Training set accuracy 4.092107e-01  |  Validation set accuracy 4.140330e-02
# Epoch 491 in 0.02 sec  |  Training set accuracy 6.462666e-01  |  Validation set accuracy 4.085799e-02
# Epoch 492 in 0.02 sec  |  Training set accuracy 2.197816e-01  |  Validation set accuracy 3.686665e-02
# Epoch 493 in 0.02 sec  |  Training set accuracy 2.809271e-01  |  Validation set accuracy 3.006201e-02
# Epoch 494 in 0.02 sec  |  Training set accuracy 1.522137e-01  |  Validation set accuracy 3.306759e-02
# Epoch 495 in 0.02 sec  |  Training set accuracy 1.472846e-01  |  Validation set accuracy 3.444529e-02
# Epoch 496 in 0.02 sec  |  Training set accuracy 2.214474e-01  |  Validation set accuracy 3.913759e-02
# Epoch 497 in 0.02 sec  |  Training set accuracy 1.643674e-01  |  Validation set accuracy 3.821658e-02
# Epoch 498 in 0.02 sec  |  Training set accuracy 1.498843e-01  |  Validation set accuracy 4.012151e-02
# Epoch 499 in 0.02 sec  |  Training set accuracy 1.281472e-01  |  Validation set accuracy 3.438222e-02
# Vessel models saved under /Users/natalia/cursor_access/learn_lpns/results/models/notebook_demo/VMR_aortas/bifurcations_EL_vessel_trial_0

# %% [markdown]
# ## 5. Inference
# Use the neural network to predict R, S, and L on the unseen test geometry.

# %%
val_dir = ZERO_D_BASE / VAL_GEO
geom_json = val_dir / "bifurcations_EL_geometric_input.json"
nn_json = val_dir / f"{GEOMETRY_VARIANT}_NN_{NN_JUNCTION_ONLY_SUFFIX}.json"
nn_junction_and_vessel_json = val_dir / f"{GEOMETRY_VARIANT}_NN_{NN_JUNCTION_AND_VESSEL_SUFFIX}.json"
nn_vessel_only_json = val_dir / f"{GEOMETRY_VARIANT}_NN_{NN_VESSEL_ONLY_SUFFIX}.json"

with open(geom_json) as f:
    nn_config = json.load(f)

jax_data = load_dict(str(jax_path))
run_junction_inference(
    jax_data_dict=jax_data,
    nn_config=nn_config,
    set_name=SET_NAME,
    geo_name=VAL_GEO,
    model_dir=str(MODEL_DIR),
    junction_type=JUNCTION_TYPE,
    quadratic_resistor=False,
)

with open(nn_json, "w") as f:
    json.dump(nn_config, f, indent=4)
print(f"Wrote {nn_json}")

with open(nn_json) as f:
    junction_nn_config = json.load(f)
junction_and_vessel_config, vessel_only_config = run_vessel_inference(
    junction_nn_config=junction_nn_config,
    variant_geometric_input=str(geom_json),
    set_name=SET_NAME,
    geometry_variant=GEOMETRY_VARIANT,
    model_dir=str(MODEL_DIR),
    quadratic_resistor=False,
    verbose=True,
)

with open(nn_junction_and_vessel_json, "w") as f:
    json.dump(junction_and_vessel_config, f, indent=4)
with open(nn_vessel_only_json, "w") as f:
    json.dump(vessel_only_config, f, indent=4)
print(f"Wrote {nn_junction_and_vessel_json}")
print(f"Wrote {nn_vessel_only_json}")
# Out:
#   Loaded 5 feature rows for 4 unique junctions
#   Junction names: ['J0_bif1', 'J0_bif3', 'J0_bif2', 'J0_bif0']
#   Selected 19 features (matching training data): ['inlet_max_inscribed_radius', 'outlet0_max_inscribed_radius_local', 'outlet0_max_inscribed_radius_min_on_path', 'outlet0_max_inscribed_radius_max_on_path', 'outlet0_rmin_rat', 'outlet0_rmax_rat', 'outlet0_path_length', 'outlet0_tortuosity', 'outlet0_angle_diff', 'outlet0_radius_ratio', 'outlet0_poiseuille_resistance_calc', 'outlet0_inductance_calc', 'outlet0_absorbed_R_poiseuille', 'outlet0_absorbed_L', 'outlet0_absorbed_stenosis_coefficient', 'flow_split_inv', 'outlet0_rneg4', 'outlet0_rneg2', 'outlet0_nd_length']
#   Neural network input dimensions: (5, 19) (rows=5, features=19)
#       Loading model 1/3: /Users/natalia/cursor_access/learn_lpns/results/models/notebook_demo/VMR_aortas/bifurcations_EL_trial_0/rri_VMR_aortas_pred_0_model
#       Loading model 2/3: /Users/natalia/cursor_access/learn_lpns/results/models/notebook_demo/VMR_aortas/bifurcations_EL_trial_0/rri_VMR_aortas_pred_1_model
#       Loading model 3/3: /Users/natalia/cursor_access/learn_lpns/results/models/notebook_demo/VMR_aortas/bifurcations_EL_trial_0/rri_VMR_aortas_pred_2_model
#       R_poiseuille: pred range=[9.2084, 231.1642]
#       stenosis_coefficient: pred range=[-0.0297, 0.0027]
#       L: pred range=[3.1951, 13.7555]
#       Built prediction mapping: 5 (junction, outlet) entries
#         (J0_bif0, branch4_seg0_connectorEL) -> row 0, vessel_id=6
#         (J0_bif1, branch2_seg0_connectorEL) -> row 1, vessel_id=4
#         (J0_bif2, branch5_seg0_connectorEL) -> row 2, vessel_id=7
#         (J0_bif3, branch3_seg0_connectorEL) -> row 3, vessel_id=5
#         (J0_bif3, branch1_seg0_1_2_connectorEL) -> row 4, vessel_id=3
#         J0_bif0: outlet[0] branch4_seg0_connectorEL (id=6) -> row 0: R=231.1642, S=0.0000, L=10.0352
#         J0_bif0: outlet[1] branch0_seg2_connector0 (id=8) -> connector, set to 0
#         J0_bif1: outlet[0] branch2_seg0_connectorEL (id=4) -> row 1: R=117.7524, S=0.0000, L=13.7555
#         J0_bif1: outlet[1] branch0_seg2_connector1 (id=9) -> connector, set to 0
#         J0_bif2: outlet[0] branch5_seg0_connectorEL (id=7) -> row 2: R=48.4800, S=0.0000, L=7.1331
#         J0_bif2: outlet[1] branch0_seg2_connector2 (id=10) -> connector, set to 0
#         J0_bif3: outlet[0] branch3_seg0_connectorEL (id=5) -> row 3: R=23.1260, S=0.0000, L=6.3471
#         J0_bif3: outlet[1] branch1_seg0_1_2_connectorEL (id=3) -> row 4: R=9.2084, S=0.0000, L=3.1951
# Wrote /Users/natalia/cursor_access/learn_lpns/data/zeroD/VMR_aortas/gen_loss/0154_0001/bifurcations_EL_NN_JunctionOnly.json
# Skipping connector vessel: branch1_seg0_1_2_connectorEL
# Skipping connector vessel: branch2_seg0_connectorEL
# Skipping connector vessel: branch3_seg0_connectorEL
# Skipping connector vessel: branch4_seg0_connectorEL
# Skipping connector vessel: branch5_seg0_connectorEL
# Skipping connector vessel: branch0_seg2_connector0
# Skipping connector vessel: branch0_seg2_connector1
# Skipping connector vessel: branch0_seg2_connector2
#       Loading model 1/3: /Users/natalia/cursor_access/learn_lpns/results/models/notebook_demo/VMR_aortas/bifurcations_EL_vessel_trial_0/rri_VMR_aortas_vessel_pred_0_model
#       Loading model 2/3: /Users/natalia/cursor_access/learn_lpns/results/models/notebook_demo/VMR_aortas/bifurcations_EL_vessel_trial_0/rri_VMR_aortas_vessel_pred_1_model
#       Loading model 3/3: /Users/natalia/cursor_access/learn_lpns/results/models/notebook_demo/VMR_aortas/bifurcations_EL_vessel_trial_0/rri_VMR_aortas_vessel_pred_2_model
#       R_poiseuille: pred range=[0.4922, 4.9440]
#       stenosis_coefficient: pred range=[-0.0004, 0.0008]
#       L: pred range=[0.1222, 0.6273]
# Wrote /Users/natalia/cursor_access/learn_lpns/data/zeroD/VMR_aortas/gen_loss/0154_0001/bifurcations_EL_NN_JunctionAndVessel.json
# Wrote /Users/natalia/cursor_access/learn_lpns/data/zeroD/VMR_aortas/gen_loss/0154_0001/bifurcations_EL_NN_VesselOnly.json

# %% [markdown]
# ### Zero-D Parameter Comparison Plot
# Visualization showing a comparison of the R, S, and L values for each junction and vessel in the test geometry, as defined the standard, calibrated, and learned 0D model input files.  We see that, even with this small dataset, the learned values are closer to the calibrated (ground truth values) than the standard values are, indicating that they match the 3D solution better.

# %%
modality_json_paths = {
    "geometric": str(geom_json),
    JUNCTION_TYPE: str(val_dir / "bifurcations_EL_calibrated_output_BloodVesselJunction.json"),
    "BloodVesselJunction_NN": str(nn_json),
    "BloodVesselJunction_NN_plus_Vessel_NN": str(nn_junction_and_vessel_json),
    "Vessel_NN": str(nn_vessel_only_json),
}

PLOT_DIR.mkdir(parents=True, exist_ok=True)
plot_path = plot_zero_d_parameter_bars(
    modality_json_paths,
    output_dir=str(PLOT_DIR),
    output_name=f"{GEOMETRY_VARIANT}_zero_d_parameter_bars.png",
    verbose=True,
)

if plot_path:
    display(Image(filename=plot_path))
else:
    print("Plot generation failed — check modality JSON paths.")
# Out:
#   ✓ Saved zero-D parameter bar chart to: /Users/natalia/cursor_access/learn_lpns/results/notebook_demo/param_comparison/gen_loss/VMR_aortas/seed_0/0154_0001/bifurcations_EL_zero_d_parameter_bars.png

# %% [markdown]
# ## 6. Forward 0D Simulation
#
# At this point, we can run 0D forward simulation on the standard 0D model, calibrated 0D model, and learned 0D model, and compare the results to the 3D reference.  We expect the calibrated model to match the 3D solution the best, followed by the learned model, and then the standard model.
#
# Forward simulation requires svzerodsolver, so we skip this and load an pre-made plot showing the 0D simulation results (flow and pressure over time) for the different simulation modalities.

# %% [markdown]
# ![3D vs 0D solutions at vasculature inlet](assets/INFLOW_branch0_inlet_comparison.png)
